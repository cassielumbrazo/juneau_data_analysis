# %% [markdown]
# ### Download HRRR Data using Herbie
#
# Notebook contents
#
# https://herbie.readthedocs.io/en/2024.3.0/user_guide/install.html
# * attempting to use Herbie to download HRRR data
#
# created by Cassie Lumbrazo\
# last updated: Jan 2025\
# run location: UAS linux\
# python environment: **herbie**\
# *created a new environment for herbie data downloader...*

# %%
# import packages 
# %matplotlib inline

# plotting packages 
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns 

sns.set_theme()
# plt.rcParams['figure.figsize'] = [12,6] #overriding size

# data packages 
import pandas as pd
import numpy as np
import xarray as xr
from datetime import datetime, timedelta

import scipy

# %%
pwd
# Out:
# '/home/cassie/python/repos/juneau_data_analysis'

# %%
from herbie import Herbie
# from toolbox import EasyMap, pc
# from paint.standard2 import cm_tmp

import matplotlib.pyplot as plt
import cartopy.crs as ccrs

import os
import glob
import rioxarray

# %% [markdown]
# Download for HRRR-AK at hour 00:00, fxx=0

# %%
H = Herbie(
    "2020-10-01 00:00",
    model="hrrrak",
    product="sfc",
    fxx=0,
)
# Out:
# ✅ Found ┊ model=hrrrak ┊ product=sfc ┊ 2020-Oct-01 00:00 UTC F00 ┊ GRIB2 @ local ┊ IDX @ aws

# %% [markdown]
# Download for HRRR-AK at hour 01:00, fxx=0

# %%
H = Herbie(
    "2020-10-01 01:00",
    model="hrrrak",
    product="sfc",
    fxx=0,
)
# Out:
# 💔 Did not find ┊ model=hrrrak ┊ product=sfc ┊ 2020-Oct-01 01:00 UTC F00

# %% [markdown]
# Download HRRR at hour 00:00, fxx=0

# %%
H = Herbie(
    "2020-10-01 00:00",
    model="hrrr",
    product="sfc",
    fxx=0,
)
# Out:
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2020-Oct-01 01:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws

# %% [markdown]
# Download HRRR at hour 01:00, fxx=0

# %%
H = Herbie(
    "2020-10-01 01:00",
    model="hrrr",
    product="sfc",
    fxx=0,
)
# Out:
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2020-Oct-01 01:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws

# %%
# show additional products 
H.PRODUCTS
# Out:
# {'prs': '3D pressure level fields; 3-km resolution',
#  'sfc': '2D surface level fields; 3-km resolution',
#  'nat': 'Native level fields; 3-km resolution',
#  'subh': 'Subhourly grids; 3-km resolution'}

# %%
H.DESCRIPTION
# Out:
# 'High-Resolution Rapid Refresh - Alaska'

# %%
H.date
# Out:
# Timestamp('2023-11-01 01:00:00')

# %%
H.DETAILS
# Out:
# {'nomads product description': 'https://www.nco.ncep.noaa.gov/pmb/products/hrrr'}

# %%
H.product_description
# Out:
# '2D surface level fields; 3-km resolution'

# %%
ds = H.xarray("TMP:2 m")
ds
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 ds = H.xarray("TMP:2 m")
#       2 ds
#
# File ~/programs/miniforge3/envs/herbie/lib/python3.13/site-packages/herbie/core.py:1094, in Herbie.xarray(self, search, searchString, backend_kwargs, remove_grib, **download_kwargs)
#    1090     search = searchString
#    1092 download_kwargs = {**dict(overwrite=False), **download_kwargs}
# -> 1094 local_file = self.get_localFilePath(search)
#    1096 if "save_dir" in download_kwargs:
#    1097     # Looks like the save_dir was changed.
#    1098     self.save_dir = Path(download_kwargs["save_dir"]).expand()
#
# File ~/programs/miniforge3/envs/herbie/lib/python3.13/site-packages/herbie/core.py:566, in Herbie.get_localFilePath(self, search, searchString)
#     555     localFilePath = next(
#     556         (
#     557             Path(self.SOURCES[i])
#    (...)
#     561         localFilePath,
#     562     )
#     564 if search is not None:
#     565     # Reassign the index DataFrame with the requested search
# --> 566     idx_df = self.inventory(search)
#     568     # ======================================
#     569     # Make a unique filename for the subset
#     570
#     571     # Get a list of all GRIB message numbers. We will use this
#     572     # in the output file name as a unique identifier.
#     573     all_grib_msg = "-".join([f"{i:g}" for i in idx_df.index])
#
# File ~/programs/miniforge3/envs/herbie/lib/python3.13/site-packages/herbie/core.py:806, in Herbie.inventory(self, search, searchString, verbose)
#     773 def inventory(
#     774     self,
#     775     search: Optional[str] = None,
#    (...)
#     778     verbose: Optional[bool] = None,
#     779 ) -> pd.DataFrame:
#     780     """
#     781     Inspect the GRIB2 file contents by reading the index file.
#     782
#    (...)
#     804
#     805     """
# --> 806     df = self.index_as_dataframe
#     808     # TODO: Remove this eventually
#     809     if searchString is not None:
#
# File ~/programs/miniforge3/envs/herbie/lib/python3.13/functools.py:1039, in cached_property.__get__(self, instance, owner)
#    1037 val = cache.get(self.attrname, _NOT_FOUND)
#    1038 if val is _NOT_FOUND:
# -> 1039     val = self.func(instance)
#    1040     try:
#    1041         cache[self.attrname] = val
#
# File ~/programs/miniforge3/envs/herbie/lib/python3.13/site-packages/herbie/core.py:620, in Herbie.index_as_dataframe(self)
#     618         self.IDX_STYLE = "wgrib2"
#     619     else:
# --> 620         raise ValueError(
#     621             f"\nNo index file was found for {self.grib}\n"
#     622             f"Download the full file first (with `H.download()`).\n"
#     623             f"You will need to remake the Herbie object (H = `Herbie()`)\n"
#     624             f"or delete this cached property: `del H.index_as_dataframe()`"
#     625         )
#     626 if self.idx is None:
#     627     raise ValueError(f"No index file found for {self.grib}.")
#
# ValueError:
# No index file was found for None
# Download the full file first (with `H.download()`).
# You will need to remake the Herbie object (H = `Herbie()`)
# or delete this cached property: `del H.index_as_dataframe()`

# %% [markdown]
# There is a herbie tool to pick data from the nearest lat/lon

# %%
points = pd.DataFrame({
    "longitude": [-100, -105, -98.4],
    "latitude": [40, 29, 42.3],
})

# Get nearest points
nearest_data = ds.herbie.pick_points(points)
# Out:
# INFO: 🌱 Growing new BallTree...🌳 BallTree grew in 0.78 seconds.
# INFO: Saved BallTree to /home/cassie/data/BallTree/hrrrak_1299-919.pkl
# WARNING: 3 points removed for exceeding max_distance=500 km threshold.
#        longitude  latitude  point_grid_distance  grid_index  y_grid  x_grid  \
# point
# 0         -100.0      40.0          2537.334043        1298       0    1298
# 1         -105.0      29.0          3186.154850        1298       0    1298
# 2          -98.4      42.3          2486.076496        1298       0    1298
#
#        latitude_grid  longitude_grid
# point
# 0           51.72556      231.526897
# 1           51.72556      231.526897
# 2           51.72556      231.526897

# %%
ds = ds.herbie.to_180()

# %%
ds.herbie.crs
# Out:
# <Projected CRS: +proj=stere +ellps=sphere +a=6371229.0 +b=6371229. ...>
# Name: unknown
# Axis Info [cartesian]:
# - E[south]: Easting (metre)
# - N[south]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unknown
# - method: Polar Stereographic (variant B)
# Datum: unknown
# - Ellipsoid: unknown
# - Prime Meridian: Greenwich

# %%
ds['t2m'].plot()

# %%
ds['t2m'].attrs
# Out:
# {'GRIB_paramId': 167,
#  'GRIB_dataType': 'fc',
#  'GRIB_numberOfPoints': 1193781,
#  'GRIB_typeOfLevel': 'heightAboveGround',
#  'GRIB_stepUnits': 1,
#  'GRIB_stepType': 'instant',
#  'GRIB_gridType': 'polar_stereographic',
#  'GRIB_NV': 0,
#  'GRIB_cfName': 'air_temperature',
#  'GRIB_cfVarName': 't2m',
#  'GRIB_gridDefinitionDescription': 'Polar stereographic can be south or north',
#  'GRIB_missingValue': 3.4028234663852886e+38,
#  'GRIB_name': '2 metre temperature',
#  'GRIB_parameterName': 'Temperature',
#  'GRIB_parameterUnits': 'K',
#  'GRIB_shortName': '2t',
#  'GRIB_stepRange': '6',
#  'GRIB_units': 'K',
#  'long_name': '2 metre temperature',
#  'units': 'K',
#  'standard_name': 'air_temperature',
#  'grid_mapping': 'gribfile_projection'}

# %% [markdown]
# That's only 2-m air temperature, there are other surface fields

# %%
H.PRODUCTS
# Out:
# {'prs': '3D pressure level fields; 3-km resolution',
#  'sfc': '2D surface level fields; 3-km resolution',
#  'nat': 'Native level fields; 3-km resolution',
#  'subh': 'Subhourly grids; 3-km resolution'}
