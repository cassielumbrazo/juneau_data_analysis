# %% [markdown]
# ### Download HRRR Data using Herbie
#
# Notebook contents
#
# https://herbie.readthedocs.io/en/2024.3.0/user_guide/install.html
# * attempting to use Herbie to download HRRR data
#
# created by Cassie Lumbrazo\
# last updated: Jan 2025\
# run location: UAS linux\
# python environment: **herbie**\
# *created a new environment for herbie data downloader...*

# %%
# import packages 
# %matplotlib inline

# plotting packages 
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns 

sns.set_theme()
# plt.rcParams['figure.figsize'] = [12,6] #overriding size

# data packages 
import pandas as pd
import numpy as np
import xarray as xr
from datetime import datetime, timedelta

import scipy

# %%
pwd
# Out:
# '/home/cassie/python/repos/juneau_data_analysis'

# %%
from herbie import Herbie
# from toolbox import EasyMap, pc
# from paint.standard2 import cm_tmp

import matplotlib.pyplot as plt
import cartopy.crs as ccrs

import os
import glob
import rioxarray

# %% [markdown]
# Download the HRRR ak dataset for a specific date to test the download.

# %%
H = Herbie(
    "2023-11-01 00:00",
    model="hrrrak",
    product="sfc",
    fxx=6,
)
# Out:
# ✅ Found ┊ model=hrrrak ┊ product=sfc ┊ 2023-Nov-01 00:00 UTC F06 ┊ GRIB2 @ aws ┊ IDX @ aws

# %%
H = Herbie(
    "2023-11-01 01:00",
    model="hrrrak",
    product="sfc",
    fxx=6,
)
# Out:
# 💔 Did not find ┊ model=hrrrak ┊ product=sfc ┊ 2023-Nov-01 01:00 UTC F06

# %%
H = Herbie(
    "2023-11-01 01:00",
    model="hrrrak",
    product="sfc",
    fxx=0,
)
# Out:
# 💔 Did not find ┊ model=hrrrak ┊ product=sfc ┊ 2023-Nov-01 01:00 UTC F00

# %%
H = Herbie(
    "2023-11-01 03:00",
    model="hrrrak",
    product="sfc",
    fxx=0,
)
# Out:
# ✅ Found ┊ model=hrrrak ┊ product=sfc ┊ 2023-Nov-01 03:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws

# %%
H = Herbie(
    "2023-11-01 03:00",
    model="hrrrak",
    product="sfc",
    fxx=6,
)
# Out:
# ✅ Found ┊ model=hrrrak ┊ product=sfc ┊ 2023-Nov-01 03:00 UTC F06 ┊ GRIB2 @ local ┊ IDX @ aws

# %% [markdown]
# ### So only data for every 3 hours is archived...

# %%
# show additional products 
H.PRODUCTS
# Out:
# {'prs': '3D pressure level fields; 3-km resolution',
#  'sfc': '2D surface level fields; 3-km resolution',
#  'nat': 'Native level fields; 3-km resolution',
#  'subh': 'Subhourly grids; 3-km resolution'}

# %% [markdown]
# So these are the product options for the `hrrrak` model

# %%
# trying a different model for the timestep which did not have data on `sfc`
H = Herbie(
    "2023-11-01 01:00",
    model="hrrrak",
    product="sfc",
)
# Out:
# 💔 Did not find ┊ model=hrrrak ┊ product=sfc ┊ 2023-Nov-01 01:00 UTC F00

# %% [markdown]
# so, the other products also do not have data archived for every hour.. only every 3 hours?

# %%
H.DESCRIPTION
# Out:
# 'High-Resolution Rapid Refresh - Alaska'

# %%
H.date
# Out:
# Timestamp('2023-11-01 00:00:00')

# %%
H.DETAILS
# Out:
# {'nomads product description': 'https://www.nco.ncep.noaa.gov/pmb/products/hrrr'}

# %%
H.product_description
# Out:
# '2D surface level fields; 3-km resolution'

# %%
ds = H.xarray("TMP:2 m")
ds
# Out:
# <xarray.Dataset> Size: 24MB
# Dimensions:              (y: 919, x: 1299)
# Coordinates:
#     time                 datetime64[ns] 8B 2023-11-01T03:00:00
#     step                 timedelta64[ns] 8B 06:00:00
#     heightAboveGround    float64 8B 2.0
#     latitude             (y, x) float64 10MB 41.61 41.63 41.64 ... 76.35 76.34
#     longitude            (y, x) float64 10MB 185.1 185.1 185.2 ... 244.1 244.2
#     valid_time           datetime64[ns] 8B 2023-11-01T09:00:00
#     gribfile_projection  object 8B None
# Dimensions without coordinates: y, x
# Data variables:
#     t2m                  (y, x) float32 5MB 284.2 284.2 284.2 ... 258.7 258.5
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     model:                   hrrrak
#     product:                 sfc
#     description:             High-Resolution Rapid Refresh - Alaska
#     remote_grib:             /home/cassie/data/hrrrak/20231101/hrrr.t03z.wrfs...
#     local_grib:              /home/cassie/data/hrrrak/20231101/subset_a0b29dd...
#     search:                  TMP:2 m

# %% [markdown]
# There is a herbie tool to pick data from the nearest lat/lon

# %%
points = pd.DataFrame({
    "longitude": [-100, -105, -98.4],
    "latitude": [40, 29, 42.3],
})

# Get nearest points
nearest_data = ds.herbie.pick_points(points)
# Out:
# INFO: 🌱 Growing new BallTree...🌳 BallTree grew in 0.78 seconds.
# INFO: Saved BallTree to /home/cassie/data/BallTree/hrrrak_1299-919.pkl
# WARNING: 3 points removed for exceeding max_distance=500 km threshold.
#        longitude  latitude  point_grid_distance  grid_index  y_grid  x_grid  \
# point
# 0         -100.0      40.0          2537.334043        1298       0    1298
# 1         -105.0      29.0          3186.154850        1298       0    1298
# 2          -98.4      42.3          2486.076496        1298       0    1298
#
#        latitude_grid  longitude_grid
# point
# 0           51.72556      231.526897
# 1           51.72556      231.526897
# 2           51.72556      231.526897

# %%
ds = ds.herbie.to_180()

# %%
ds.herbie.crs
# Out:
# <Projected CRS: +proj=stere +ellps=sphere +a=6371229.0 +b=6371229. ...>
# Name: unknown
# Axis Info [cartesian]:
# - E[south]: Easting (metre)
# - N[south]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unknown
# - method: Polar Stereographic (variant B)
# Datum: unknown
# - Ellipsoid: unknown
# - Prime Meridian: Greenwich

# %%
ds['t2m'].plot()

# %%
ds['t2m'].attrs
# Out:
# {'GRIB_paramId': 167,
#  'GRIB_dataType': 'fc',
#  'GRIB_numberOfPoints': 1193781,
#  'GRIB_typeOfLevel': 'heightAboveGround',
#  'GRIB_stepUnits': 1,
#  'GRIB_stepType': 'instant',
#  'GRIB_gridType': 'polar_stereographic',
#  'GRIB_NV': 0,
#  'GRIB_cfName': 'air_temperature',
#  'GRIB_cfVarName': 't2m',
#  'GRIB_gridDefinitionDescription': 'Polar stereographic can be south or north',
#  'GRIB_missingValue': 3.4028234663852886e+38,
#  'GRIB_name': '2 metre temperature',
#  'GRIB_parameterName': 'Temperature',
#  'GRIB_parameterUnits': 'K',
#  'GRIB_shortName': '2t',
#  'GRIB_stepRange': '6',
#  'GRIB_units': 'K',
#  'long_name': '2 metre temperature',
#  'units': 'K',
#  'standard_name': 'air_temperature',
#  'grid_mapping': 'gribfile_projection'}

# %% [markdown]
# That's only 2-m air temperature, there are other surface fields

# %%
H.PRODUCTS
# Out:
# {'prs': '3D pressure level fields; 3-km resolution',
#  'sfc': '2D surface level fields; 3-km resolution',
#  'nat': 'Native level fields; 3-km resolution',
#  'subh': 'Subhourly grids; 3-km resolution'}

# %% [markdown]
# ## A test to download hourly data using Herbie then put it all together

# %% [markdown]
# This code is working. The only issue is that the hourly data won't download, only every 3 hours.\
# But that is not an issue with the code, it's an error with the download itself.

# %%
# Define parameters
START_DATE = "2023-10-01"  # start date
END_DATE = "2023-10-02"    # end date
MODEL = "hrrrak"           # HRRR-AK model
SUBMODEL = "ak"            # Alaska-specific domain
# VARIABLES = ["TMP:2 m", "UGRD:10 m", "VGRD:10 m"]  # Example variables to download
VARIABLES = [
    "TMP:2 m",  # Temperature at 2 meters
    "UGRD:10 m",  # U wind component at 10 meters
    "VGRD:10 m",  # V wind component at 10 meters
    "SPFH:2 m",  # Specific humidity at 2 meters
    "PRES:surface",  # Surface pressure
    "VIS:surface",  # Visibility
    "SWDOWN:surface",  # Surface shortwave radiation flux
    "LWDOWN:surface",  # Surface longwave radiation flux
    "APCP:surface",  # Accumulated precipitation
    "TCDC:surface",  # Total cloud cover
    "SFC:soil moisture and temperature",  # Soil moisture and temperature
    "HGT:surface",  # Surface geopotential height
    "RH:2 m",  # Relative humidity at 2 meters
    "U:10 m",  # U wind component at 10 meters
    "V:10 m"  # V wind component at 10 meters
]  # Example variables to download

# Paths for saving files
HOURLY_DIR = "/home/cassie/data/hrrrak/netcdf"  # Directory for hourly files
MERGE_FILE = "/home/cassie/data/hrrrak/netcdf/netcdf_merge.nc"  # Final merged file

# Create directories if they don't exist
os.makedirs(HOURLY_DIR, exist_ok=True)

# Generate a date range for downloading
date_range = pd.date_range(START_DATE, END_DATE, freq="1h")

# Step 1: Download hourly HRRR-AK data
for date in date_range:
    try:
        print(f"Processing: {date}")
        h = Herbie(date, model=MODEL, product="sfc", domain=SUBMODEL)

        # Check available variables (optional)
        print(h.inventory())

        # Initialize an empty list to store datasets
        datasets = []

        # Loop through each variable and load
        for variable in VARIABLES:
            try:
                ds = h.xarray(variable)
                datasets.append(ds)
            except Exception as e:
                print(f"Error loading variable {variable}: {e}")

        # Merge all datasets, overriding metadata conflicts
        if datasets:
            combined_ds = xr.merge(datasets, compat="override")

            # Save hourly NetCDF
            netcdf_path = os.path.join(HOURLY_DIR, f"HRRR_AK_{date.strftime('%Y%m%d%H')}.nc")
            combined_ds.to_netcdf(netcdf_path)
            print(f"Saved hourly NetCDF: {netcdf_path}")
    except Exception as e:
        print(f"Error processing {date}: {e}")
# Out:
# Processing: 2023-10-01 00:00:00
# ✅ Found ┊ model=hrrrak ┊ product=sfc ┊ 2023-Oct-01 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
#      grib_message  start_byte    end_byte              range reference_time  \
# 0               1           0    511845.0           0-511845     2023-10-01
# 1               2      511846    704072.0      511846-704072     2023-10-01
# 2               3      704073   1221366.0     704073-1221366     2023-10-01
# 3               4     1221367   1549890.0    1221367-1549890     2023-10-01
# 4               5     1549891   2264915.0    1549891-2264915     2023-10-01
# ..            ...         ...         ...                ...            ...
# 164           165    82563874  82571400.0  82563874-82571400     2023-10-01
# 165           166    82571401  82733809.0  82571401-82733809     2023-10-01
# 166           167    82733810  82904774.0  82733810-82904774     2023-10-01
# 167           168    82904775  83557293.0  82904775-83557293     2023-10-01
# 168           169    83557294         NaN          83557294-     2023-10-01
#
#     valid_time                                           variable  \
# 0   2023-10-01                                               REFC
# 1   2023-10-01                                              RETOP
# 2   2023-10-01  var discipline=0 center=7 local_table=1 parmca...
# 3   2023-10-01                                                VIL
# 4   2023-10-01                                                VIS
# ..         ...                                                ...
# 164 2023-10-01                                               ICEC
# 165 2023-10-01                                             SBT123
# 166 2023-10-01                                             SBT124
# 167 2023-10-01                                             SBT113
# 168 2023-10-01                                             SBT114
#
#                  level forecast_time  \
# 0    entire atmosphere           anl
# 1            cloud top           anl
# 2    entire atmosphere           anl
# 3    entire atmosphere           anl
# 4              surface           anl
# ..                 ...           ...
# 164            surface           anl
# 165  top of atmosphere           anl
# 166  top of atmosphere           anl
# 167  top of atmosphere           anl
# 168  top of atmosphere           anl
#
#                                            search_this
# 0                          :REFC:entire atmosphere:anl
# 1                                 :RETOP:cloud top:anl
# 2    :var discipline=0 center=7 local_table=1 parmc...
# 3                           :VIL:entire atmosphere:anl
# 4                                     :VIS:surface:anl
# ..                                                 ...
# 164                                  :ICEC:surface:anl
# 165                      :SBT123:top of atmosphere:anl
# 166                      :SBT124:top of atmosphere:anl
# 167                      :SBT113:top of atmosphere:anl
# 168                      :SBT114:top of atmosphere:anl
#
# [169 rows x 10 columns]
# 👨🏻‍🏭 Created directory: [/home/cassie/data/hrrrak/20231001]
# Error loading variable SWDOWN:surface: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_35efb1fe__hrrr.t00z.wrfsfcf00.ak.grib2'
# Error loading variable LWDOWN:surface: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_35efb1fe__hrrr.t00z.wrfsfcf00.ak.grib2'
# Error loading variable TCDC:surface: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_35efb1fe__hrrr.t00z.wrfsfcf00.ak.grib2'
# Error loading variable SFC:soil moisture and temperature: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_35efb1fe__hrrr.t00z.wrfsfcf00.ak.grib2'
# Error loading variable U:10 m: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_35efb1fe__hrrr.t00z.wrfsfcf00.ak.grib2'
# Error loading variable V:10 m: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_35efb1fe__hrrr.t00z.wrfsfcf00.ak.grib2'
# Saved hourly NetCDF: /home/cassie/data/hrrrak/netcdf/HRRR_AK_2023100100.nc
# Processing: 2023-10-01 01:00:00
# 💔 Did not find ┊ model=hrrrak ┊ product=sfc ┊ 2023-Oct-01 01:00 UTC F00
# Error processing 2023-10-01 01:00:00:
# No index file was found for None
# Download the full file first (with `H.download()`).
# You will need to remake the Herbie object (H = `Herbie()`)
# or delete this cached property: `del H.index_as_dataframe()`
# Processing: 2023-10-01 02:00:00
# 💔 Did not find ┊ model=hrrrak ┊ product=sfc ┊ 2023-Oct-01 02:00 UTC F00
# Error processing 2023-10-01 02:00:00:
# No index file was found for None
# Download the full file first (with `H.download()`).
# You will need to remake the Herbie object (H = `Herbie()`)
# or delete this cached property: `del H.index_as_dataframe()`
# Processing: 2023-10-01 03:00:00
# ✅ Found ┊ model=hrrrak ┊ product=sfc ┊ 2023-Oct-01 03:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
#      grib_message  start_byte    end_byte              range  \
# 0               1           0    546026.0           0-546026
# 1               2      546027    747737.0      546027-747737
# 2               3      747738   1402800.0     747738-1402800
# 3               4     1402801   1863384.0    1402801-1863384
# 4               5     1863385   2588088.0    1863385-2588088
# ..            ...         ...         ...                ...
# 164           165    79968566  79976087.0  79968566-79976087
# 165           166    79976088  80149037.0  79976088-80149037
# 166           167    80149038  80318904.0  80149038-80318904
# 167           168    80318905  80977100.0  80318905-80977100
# 168           169    80977101         NaN          80977101-
#
#          reference_time          valid_time  \
# 0   2023-10-01 03:00:00 2023-10-01 03:00:00
# 1   2023-10-01 03:00:00 2023-10-01 03:00:00
# 2   2023-10-01 03:00:00 2023-10-01 03:00:00
# 3   2023-10-01 03:00:00 2023-10-01 03:00:00
# 4   2023-10-01 03:00:00 2023-10-01 03:00:00
# ..                  ...                 ...
# 164 2023-10-01 03:00:00 2023-10-01 03:00:00
# 165 2023-10-01 03:00:00 2023-10-01 03:00:00
# 166 2023-10-01 03:00:00 2023-10-01 03:00:00
# 167 2023-10-01 03:00:00 2023-10-01 03:00:00
# 168 2023-10-01 03:00:00 2023-10-01 03:00:00
#
#                                               variable              level  \
# 0                                                 REFC  entire atmosphere
# 1                                                RETOP          cloud top
# 2    var discipline=0 center=7 local_table=1 parmca...  entire atmosphere
# 3                                                  VIL  entire atmosphere
# 4                                                  VIS            surface
# ..                                                 ...                ...
# 164                                               ICEC            surface
# 165                                             SBT123  top of atmosphere
# 166                                             SBT124  top of atmosphere
# 167                                             SBT113  top of atmosphere
# 168                                             SBT114  top of atmosphere
#
#     forecast_time                                        search_this
# 0             anl                        :REFC:entire atmosphere:anl
# 1             anl                               :RETOP:cloud top:anl
# 2             anl  :var discipline=0 center=7 local_table=1 parmc...
# 3             anl                         :VIL:entire atmosphere:anl
# 4             anl                                   :VIS:surface:anl
# ..            ...                                                ...
# 164           anl                                  :ICEC:surface:anl
# 165           anl                      :SBT123:top of atmosphere:anl
# 166           anl                      :SBT124:top of atmosphere:anl
# 167           anl                      :SBT113:top of atmosphere:anl
# 168           anl                      :SBT114:top of atmosphere:anl
#
# [169 rows x 10 columns]
# Error loading variable SWDOWN:surface: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_e4efb1fe__hrrr.t03z.wrfsfcf00.ak.grib2'
# Error loading variable LWDOWN:surface: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_e4efb1fe__hrrr.t03z.wrfsfcf00.ak.grib2'
# Error loading variable TCDC:surface: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_e4efb1fe__hrrr.t03z.wrfsfcf00.ak.grib2'
# Error loading variable SFC:soil moisture and temperature: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_e4efb1fe__hrrr.t03z.wrfsfcf00.ak.grib2'
# Error loading variable U:10 m: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_e4efb1fe__hrrr.t03z.wrfsfcf00.ak.grib2'
# Error loading variable V:10 m: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_e4efb1fe__hrrr.t03z.wrfsfcf00.ak.grib2'
# Saved hourly NetCDF: /home/cassie/data/hrrrak/netcdf/HRRR_AK_2023100103.nc
# Processing: 2023-10-01 04:00:00
# 💔 Did not find ┊ model=hrrrak ┊ product=sfc ┊ 2023-Oct-01 04:00 UTC F00
# Error processing 2023-10-01 04:00:00:
# No index file was found for None
# Download the full file first (with `H.download()`).
# You will need to remake the Herbie object (H = `Herbie()`)
# or delete this cached property: `del H.index_as_dataframe()`
# Processing: 2023-10-01 05:00:00
# 💔 Did not find ┊ model=hrrrak ┊ product=sfc ┊ 2023-Oct-01 05:00 UTC F00
# Error processing 2023-10-01 05:00:00:
# No index file was found for None
# Download the full file first (with `H.download()`).
# You will need to remake the Herbie object (H = `Herbie()`)
# or delete this cached property: `del H.index_as_dataframe()`
# Processing: 2023-10-01 06:00:00
# ✅ Found ┊ model=hrrrak ┊ product=sfc ┊ 2023-Oct-01 06:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
#      grib_message  start_byte    end_byte              range  \
# 0               1           0    612108.0           0-612108
# 1               2      612109    835055.0      612109-835055
# 2               3      835056   1548752.0     835056-1548752
# 3               4     1548753   2063422.0    1548753-2063422
# 4               5     2063423   2810670.0    2063423-2810670
# ..            ...         ...         ...                ...
# 164           165    76648391  76655912.0  76648391-76655912
# 165           166    76655913  76820686.0  76655913-76820686
# 166           167    76820687  76992747.0  76820687-76992747
# 167           168    76992748  77656524.0  76992748-77656524
# 168           169    77656525         NaN          77656525-
#
#          reference_time          valid_time  \
# 0   2023-10-01 06:00:00 2023-10-01 06:00:00
# 1   2023-10-01 06:00:00 2023-10-01 06:00:00
# 2   2023-10-01 06:00:00 2023-10-01 06:00:00
# 3   2023-10-01 06:00:00 2023-10-01 06:00:00
# 4   2023-10-01 06:00:00 2023-10-01 06:00:00
# ..                  ...                 ...
# 164 2023-10-01 06:00:00 2023-10-01 06:00:00
# 165 2023-10-01 06:00:00 2023-10-01 06:00:00
# 166 2023-10-01 06:00:00 2023-10-01 06:00:00
# 167 2023-10-01 06:00:00 2023-10-01 06:00:00
# 168 2023-10-01 06:00:00 2023-10-01 06:00:00
#
#                                               variable              level  \
# 0                                                 REFC  entire atmosphere
# 1                                                RETOP          cloud top
# 2    var discipline=0 center=7 local_table=1 parmca...  entire atmosphere
# 3                                                  VIL  entire atmosphere
# 4                                                  VIS            surface
# ..                                                 ...                ...
# 164                                               ICEC            surface
# 165                                             SBT123  top of atmosphere
# 166                                             SBT124  top of atmosphere
# 167                                             SBT113  top of atmosphere
# 168                                             SBT114  top of atmosphere
#
#     forecast_time                                        search_this
# 0             anl                        :REFC:entire atmosphere:anl
# 1             anl                               :RETOP:cloud top:anl
# 2             anl  :var discipline=0 center=7 local_table=1 parmc...
# 3             anl                         :VIL:entire atmosphere:anl
# 4             anl                                   :VIS:surface:anl
# ..            ...                                                ...
# 164           anl                                  :ICEC:surface:anl
# 165           anl                      :SBT123:top of atmosphere:anl
# 166           anl                      :SBT124:top of atmosphere:anl
# 167           anl                      :SBT113:top of atmosphere:anl
# 168           anl                      :SBT114:top of atmosphere:anl
#
# [169 rows x 10 columns]
# Error loading variable SWDOWN:surface: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_83efb1fe__hrrr.t06z.wrfsfcf00.ak.grib2'
# Error loading variable LWDOWN:surface: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_83efb1fe__hrrr.t06z.wrfsfcf00.ak.grib2'
# Error loading variable TCDC:surface: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_83efb1fe__hrrr.t06z.wrfsfcf00.ak.grib2'
# Error loading variable SFC:soil moisture and temperature: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_83efb1fe__hrrr.t06z.wrfsfcf00.ak.grib2'
# Error loading variable U:10 m: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_83efb1fe__hrrr.t06z.wrfsfcf00.ak.grib2'
# Error loading variable V:10 m: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_83efb1fe__hrrr.t06z.wrfsfcf00.ak.grib2'
# Saved hourly NetCDF: /home/cassie/data/hrrrak/netcdf/HRRR_AK_2023100106.nc
# Processing: 2023-10-01 07:00:00
# 💔 Did not find ┊ model=hrrrak ┊ product=sfc ┊ 2023-Oct-01 07:00 UTC F00
# Error processing 2023-10-01 07:00:00:
# No index file was found for None
# Download the full file first (with `H.download()`).
# You will need to remake the Herbie object (H = `Herbie()`)
# or delete this cached property: `del H.index_as_dataframe()`
# Processing: 2023-10-01 08:00:00
# 💔 Did not find ┊ model=hrrrak ┊ product=sfc ┊ 2023-Oct-01 08:00 UTC F00
# Error processing 2023-10-01 08:00:00:
# No index file was found for None
# Download the full file first (with `H.download()`).
# You will need to remake the Herbie object (H = `Herbie()`)
# or delete this cached property: `del H.index_as_dataframe()`
# Processing: 2023-10-01 09:00:00
# ✅ Found ┊ model=hrrrak ┊ product=sfc ┊ 2023-Oct-01 09:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
#      grib_message  start_byte    end_byte              range  \
# 0               1           0    626331.0           0-626331
# 1               2      626332    855380.0      626332-855380
# 2               3      855381   1601337.0     855381-1601337
# 3               4     1601338   2051118.0    1601338-2051118
# 4               5     2051119   2804566.0    2051119-2804566
# ..            ...         ...         ...                ...
# 164           165    77916960  77924481.0  77916960-77924481
# 165           166    77924482  78090580.0  77924482-78090580
# 166           167    78090581  78263311.0  78090581-78263311
# 167           168    78263312  78919859.0  78263312-78919859
# 168           169    78919860         NaN          78919860-
#
#          reference_time          valid_time  \
# 0   2023-10-01 09:00:00 2023-10-01 09:00:00
# 1   2023-10-01 09:00:00 2023-10-01 09:00:00
# 2   2023-10-01 09:00:00 2023-10-01 09:00:00
# 3   2023-10-01 09:00:00 2023-10-01 09:00:00
# 4   2023-10-01 09:00:00 2023-10-01 09:00:00
# ..                  ...                 ...
# 164 2023-10-01 09:00:00 2023-10-01 09:00:00
# 165 2023-10-01 09:00:00 2023-10-01 09:00:00
# 166 2023-10-01 09:00:00 2023-10-01 09:00:00
# 167 2023-10-01 09:00:00 2023-10-01 09:00:00
# 168 2023-10-01 09:00:00 2023-10-01 09:00:00
#
#                                               variable              level  \
# 0                                                 REFC  entire atmosphere
# 1                                                RETOP          cloud top
# 2    var discipline=0 center=7 local_table=1 parmca...  entire atmosphere
# 3                                                  VIL  entire atmosphere
# 4                                                  VIS            surface
# ..                                                 ...                ...
# 164                                               ICEC            surface
# 165                                             SBT123  top of atmosphere
# 166                                             SBT124  top of atmosphere
# 167                                             SBT113  top of atmosphere
# 168                                             SBT114  top of atmosphere
#
#     forecast_time                                        search_this
# 0             anl                        :REFC:entire atmosphere:anl
# 1             anl                               :RETOP:cloud top:anl
# 2             anl  :var discipline=0 center=7 local_table=1 parmc...
# 3             anl                         :VIL:entire atmosphere:anl
# 4             anl                                   :VIS:surface:anl
# ..            ...                                                ...
# 164           anl                                  :ICEC:surface:anl
# 165           anl                      :SBT123:top of atmosphere:anl
# 166           anl                      :SBT124:top of atmosphere:anl
# 167           anl                      :SBT113:top of atmosphere:anl
# 168           anl                      :SBT114:top of atmosphere:anl
#
# [169 rows x 10 columns]
# Error loading variable SWDOWN:surface: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_12efb1fe__hrrr.t09z.wrfsfcf00.ak.grib2'
# Error loading variable LWDOWN:surface: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_12efb1fe__hrrr.t09z.wrfsfcf00.ak.grib2'
# Error loading variable TCDC:surface: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_12efb1fe__hrrr.t09z.wrfsfcf00.ak.grib2'
# Error loading variable SFC:soil moisture and temperature: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_12efb1fe__hrrr.t09z.wrfsfcf00.ak.grib2'
# Error loading variable U:10 m: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_12efb1fe__hrrr.t09z.wrfsfcf00.ak.grib2'
# Error loading variable V:10 m: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_12efb1fe__hrrr.t09z.wrfsfcf00.ak.grib2'
# Saved hourly NetCDF: /home/cassie/data/hrrrak/netcdf/HRRR_AK_2023100109.nc
# Processing: 2023-10-01 10:00:00
# 💔 Did not find ┊ model=hrrrak ┊ product=sfc ┊ 2023-Oct-01 10:00 UTC F00
# Error processing 2023-10-01 10:00:00:
# No index file was found for None
# Download the full file first (with `H.download()`).
# You will need to remake the Herbie object (H = `Herbie()`)
# or delete this cached property: `del H.index_as_dataframe()`
# Processing: 2023-10-01 11:00:00
# 💔 Did not find ┊ model=hrrrak ┊ product=sfc ┊ 2023-Oct-01 11:00 UTC F00
# Error processing 2023-10-01 11:00:00:
# No index file was found for None
# Download the full file first (with `H.download()`).
# You will need to remake the Herbie object (H = `Herbie()`)
# or delete this cached property: `del H.index_as_dataframe()`
# Processing: 2023-10-01 12:00:00
# ✅ Found ┊ model=hrrrak ┊ product=sfc ┊ 2023-Oct-01 12:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
#      grib_message  start_byte    end_byte              range  \
# 0               1           0    556854.0           0-556854
# 1               2      556855    741545.0      556855-741545
# 2               3      741546   1382380.0     741546-1382380
# 3               4     1382381   1784463.0    1382381-1784463
# 4               5     1784464   2525790.0    1784464-2525790
# ..            ...         ...         ...                ...
# 164           165    76645615  76653459.0  76645615-76653459
# 165           166    76653460  76823404.0  76653460-76823404
# 166           167    76823405  76995948.0  76823405-76995948
# 167           168    76995949  77618532.0  76995949-77618532
# 168           169    77618533         NaN          77618533-
#
#          reference_time          valid_time  \
# 0   2023-10-01 12:00:00 2023-10-01 12:00:00
# 1   2023-10-01 12:00:00 2023-10-01 12:00:00
# 2   2023-10-01 12:00:00 2023-10-01 12:00:00
# 3   2023-10-01 12:00:00 2023-10-01 12:00:00
# 4   2023-10-01 12:00:00 2023-10-01 12:00:00
# ..                  ...                 ...
# 164 2023-10-01 12:00:00 2023-10-01 12:00:00
# 165 2023-10-01 12:00:00 2023-10-01 12:00:00
# 166 2023-10-01 12:00:00 2023-10-01 12:00:00
# 167 2023-10-01 12:00:00 2023-10-01 12:00:00
# 168 2023-10-01 12:00:00 2023-10-01 12:00:00
#
#                                               variable              level  \
# 0                                                 REFC  entire atmosphere
# 1                                                RETOP          cloud top
# 2    var discipline=0 center=7 local_table=1 parmca...  entire atmosphere
# 3                                                  VIL  entire atmosphere
# 4                                                  VIS            surface
# ..                                                 ...                ...
# 164                                               ICEC            surface
# 165                                             SBT123  top of atmosphere
# 166                                             SBT124  top of atmosphere
# 167                                             SBT113  top of atmosphere
# 168                                             SBT114  top of atmosphere
#
#     forecast_time                                        search_this
# 0             anl                        :REFC:entire atmosphere:anl
# 1             anl                               :RETOP:cloud top:anl
# 2             anl  :var discipline=0 center=7 local_table=1 parmc...
# 3             anl                         :VIL:entire atmosphere:anl
# 4             anl                                   :VIS:surface:anl
# ..            ...                                                ...
# 164           anl                                  :ICEC:surface:anl
# 165           anl                      :SBT123:top of atmosphere:anl
# 166           anl                      :SBT124:top of atmosphere:anl
# 167           anl                      :SBT113:top of atmosphere:anl
# 168           anl                      :SBT114:top of atmosphere:anl
#
# [169 rows x 10 columns]
# Error loading variable SWDOWN:surface: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_10efb1fe__hrrr.t12z.wrfsfcf00.ak.grib2'
# Error loading variable LWDOWN:surface: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_10efb1fe__hrrr.t12z.wrfsfcf00.ak.grib2'
# Error loading variable TCDC:surface: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_10efb1fe__hrrr.t12z.wrfsfcf00.ak.grib2'
# Error loading variable SFC:soil moisture and temperature: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_10efb1fe__hrrr.t12z.wrfsfcf00.ak.grib2'
# Error loading variable U:10 m: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_10efb1fe__hrrr.t12z.wrfsfcf00.ak.grib2'
# Error loading variable V:10 m: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_10efb1fe__hrrr.t12z.wrfsfcf00.ak.grib2'
# Saved hourly NetCDF: /home/cassie/data/hrrrak/netcdf/HRRR_AK_2023100112.nc
# Processing: 2023-10-01 13:00:00
# 💔 Did not find ┊ model=hrrrak ┊ product=sfc ┊ 2023-Oct-01 13:00 UTC F00
# Error processing 2023-10-01 13:00:00:
# No index file was found for None
# Download the full file first (with `H.download()`).
# You will need to remake the Herbie object (H = `Herbie()`)
# or delete this cached property: `del H.index_as_dataframe()`
# Processing: 2023-10-01 14:00:00
# 💔 Did not find ┊ model=hrrrak ┊ product=sfc ┊ 2023-Oct-01 14:00 UTC F00
# Error processing 2023-10-01 14:00:00:
# No index file was found for None
# Download the full file first (with `H.download()`).
# You will need to remake the Herbie object (H = `Herbie()`)
# or delete this cached property: `del H.index_as_dataframe()`
# Processing: 2023-10-01 15:00:00
# ✅ Found ┊ model=hrrrak ┊ product=sfc ┊ 2023-Oct-01 15:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
#      grib_message  start_byte    end_byte              range  \
# 0               1           0    591885.0           0-591885
# 1               2      591886    770895.0      591886-770895
# 2               3      770896   1445789.0     770896-1445789
# 3               4     1445790   2098362.0    1445790-2098362
# 4               5     2098363   2853370.0    2098363-2853370
# ..            ...         ...         ...                ...
# 164           165    79013616  79021460.0  79013616-79021460
# 165           166    79021461  79193614.0  79021461-79193614
# 166           167    79193615  79365731.0  79193615-79365731
# 167           168    79365732  79989910.0  79365732-79989910
# 168           169    79989911         NaN          79989911-
#
#          reference_time          valid_time  \
# 0   2023-10-01 15:00:00 2023-10-01 15:00:00
# 1   2023-10-01 15:00:00 2023-10-01 15:00:00
# 2   2023-10-01 15:00:00 2023-10-01 15:00:00
# 3   2023-10-01 15:00:00 2023-10-01 15:00:00
# 4   2023-10-01 15:00:00 2023-10-01 15:00:00
# ..                  ...                 ...
# 164 2023-10-01 15:00:00 2023-10-01 15:00:00
# 165 2023-10-01 15:00:00 2023-10-01 15:00:00
# 166 2023-10-01 15:00:00 2023-10-01 15:00:00
# 167 2023-10-01 15:00:00 2023-10-01 15:00:00
# 168 2023-10-01 15:00:00 2023-10-01 15:00:00
#
#                                               variable              level  \
# 0                                                 REFC  entire atmosphere
# 1                                                RETOP          cloud top
# 2    var discipline=0 center=7 local_table=1 parmca...  entire atmosphere
# 3                                                  VIL  entire atmosphere
# 4                                                  VIS            surface
# ..                                                 ...                ...
# 164                                               ICEC            surface
# 165                                             SBT123  top of atmosphere
# 166                                             SBT124  top of atmosphere
# 167                                             SBT113  top of atmosphere
# 168                                             SBT114  top of atmosphere
#
#     forecast_time                                        search_this
# 0             anl                        :REFC:entire atmosphere:anl
# 1             anl                               :RETOP:cloud top:anl
# 2             anl  :var discipline=0 center=7 local_table=1 parmc...
# 3             anl                         :VIL:entire atmosphere:anl
# 4             anl                                   :VIS:surface:anl
# ..            ...                                                ...
# 164           anl                                  :ICEC:surface:anl
# 165           anl                      :SBT123:top of atmosphere:anl
# 166           anl                      :SBT124:top of atmosphere:anl
# 167           anl                      :SBT113:top of atmosphere:anl
# 168           anl                      :SBT114:top of atmosphere:anl
#
# [169 rows x 10 columns]
# Error loading variable SWDOWN:surface: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_c2efb1fe__hrrr.t15z.wrfsfcf00.ak.grib2'
# Error loading variable LWDOWN:surface: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_c2efb1fe__hrrr.t15z.wrfsfcf00.ak.grib2'
# Error loading variable TCDC:surface: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_c2efb1fe__hrrr.t15z.wrfsfcf00.ak.grib2'
# Error loading variable SFC:soil moisture and temperature: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_c2efb1fe__hrrr.t15z.wrfsfcf00.ak.grib2'
# Error loading variable U:10 m: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_c2efb1fe__hrrr.t15z.wrfsfcf00.ak.grib2'
# Error loading variable V:10 m: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_c2efb1fe__hrrr.t15z.wrfsfcf00.ak.grib2'
# Saved hourly NetCDF: /home/cassie/data/hrrrak/netcdf/HRRR_AK_2023100115.nc
# Processing: 2023-10-01 16:00:00
# 💔 Did not find ┊ model=hrrrak ┊ product=sfc ┊ 2023-Oct-01 16:00 UTC F00
# Error processing 2023-10-01 16:00:00:
# No index file was found for None
# Download the full file first (with `H.download()`).
# You will need to remake the Herbie object (H = `Herbie()`)
# or delete this cached property: `del H.index_as_dataframe()`
# Processing: 2023-10-01 17:00:00
# 💔 Did not find ┊ model=hrrrak ┊ product=sfc ┊ 2023-Oct-01 17:00 UTC F00
# Error processing 2023-10-01 17:00:00:
# No index file was found for None
# Download the full file first (with `H.download()`).
# You will need to remake the Herbie object (H = `Herbie()`)
# or delete this cached property: `del H.index_as_dataframe()`
# Processing: 2023-10-01 18:00:00
# ✅ Found ┊ model=hrrrak ┊ product=sfc ┊ 2023-Oct-01 18:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
#      grib_message  start_byte    end_byte              range  \
# 0               1           0    609694.0           0-609694
# 1               2      609695    793610.0      609695-793610
# 2               3      793611   1600435.0     793611-1600435
# 3               4     1600436   2187728.0    1600436-2187728
# 4               5     2187729   2934375.0    2187729-2934375
# ..            ...         ...         ...                ...
# 164           165    83538662  83546506.0  83538662-83546506
# 165           166    83546507  83721654.0  83546507-83721654
# 166           167    83721655  83893747.0  83721655-83893747
# 167           168    83893748  84528158.0  83893748-84528158
# 168           169    84528159         NaN          84528159-
#
#          reference_time          valid_time  \
# 0   2023-10-01 18:00:00 2023-10-01 18:00:00
# 1   2023-10-01 18:00:00 2023-10-01 18:00:00
# 2   2023-10-01 18:00:00 2023-10-01 18:00:00
# 3   2023-10-01 18:00:00 2023-10-01 18:00:00
# 4   2023-10-01 18:00:00 2023-10-01 18:00:00
# ..                  ...                 ...
# 164 2023-10-01 18:00:00 2023-10-01 18:00:00
# 165 2023-10-01 18:00:00 2023-10-01 18:00:00
# 166 2023-10-01 18:00:00 2023-10-01 18:00:00
# 167 2023-10-01 18:00:00 2023-10-01 18:00:00
# 168 2023-10-01 18:00:00 2023-10-01 18:00:00
#
#                                               variable              level  \
# 0                                                 REFC  entire atmosphere
# 1                                                RETOP          cloud top
# 2    var discipline=0 center=7 local_table=1 parmca...  entire atmosphere
# 3                                                  VIL  entire atmosphere
# 4                                                  VIS            surface
# ..                                                 ...                ...
# 164                                               ICEC            surface
# 165                                             SBT123  top of atmosphere
# 166                                             SBT124  top of atmosphere
# 167                                             SBT113  top of atmosphere
# 168                                             SBT114  top of atmosphere
#
#     forecast_time                                        search_this
# 0             anl                        :REFC:entire atmosphere:anl
# 1             anl                               :RETOP:cloud top:anl
# 2             anl  :var discipline=0 center=7 local_table=1 parmc...
# 3             anl                         :VIL:entire atmosphere:anl
# 4             anl                                   :VIS:surface:anl
# ..            ...                                                ...
# 164           anl                                  :ICEC:surface:anl
# 165           anl                      :SBT123:top of atmosphere:anl
# 166           anl                      :SBT124:top of atmosphere:anl
# 167           anl                      :SBT113:top of atmosphere:anl
# 168           anl                      :SBT114:top of atmosphere:anl
#
# [169 rows x 10 columns]
# Error loading variable SWDOWN:surface: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_85efb1fe__hrrr.t18z.wrfsfcf00.ak.grib2'
# Error loading variable LWDOWN:surface: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_85efb1fe__hrrr.t18z.wrfsfcf00.ak.grib2'
# Error loading variable TCDC:surface: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_85efb1fe__hrrr.t18z.wrfsfcf00.ak.grib2'
# Error loading variable SFC:soil moisture and temperature: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_85efb1fe__hrrr.t18z.wrfsfcf00.ak.grib2'
# Error loading variable U:10 m: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_85efb1fe__hrrr.t18z.wrfsfcf00.ak.grib2'
# Error loading variable V:10 m: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_85efb1fe__hrrr.t18z.wrfsfcf00.ak.grib2'
# Saved hourly NetCDF: /home/cassie/data/hrrrak/netcdf/HRRR_AK_2023100118.nc
# Processing: 2023-10-01 19:00:00
# 💔 Did not find ┊ model=hrrrak ┊ product=sfc ┊ 2023-Oct-01 19:00 UTC F00
# Error processing 2023-10-01 19:00:00:
# No index file was found for None
# Download the full file first (with `H.download()`).
# You will need to remake the Herbie object (H = `Herbie()`)
# or delete this cached property: `del H.index_as_dataframe()`
# Processing: 2023-10-01 20:00:00
# 💔 Did not find ┊ model=hrrrak ┊ product=sfc ┊ 2023-Oct-01 20:00 UTC F00
# Error processing 2023-10-01 20:00:00:
# No index file was found for None
# Download the full file first (with `H.download()`).
# You will need to remake the Herbie object (H = `Herbie()`)
# or delete this cached property: `del H.index_as_dataframe()`
# Processing: 2023-10-01 21:00:00
# ✅ Found ┊ model=hrrrak ┊ product=sfc ┊ 2023-Oct-01 21:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
#      grib_message  start_byte    end_byte              range  \
# 0               1           0    573613.0           0-573613
# 1               2      573614    742305.0      573614-742305
# 2               3      742306   1425771.0     742306-1425771
# 3               4     1425772   1992216.0    1425772-1992216
# 4               5     1992217   2740808.0    1992217-2740808
# ..            ...         ...         ...                ...
# 164           165    85075401  85083249.0  85075401-85083249
# 165           166    85083250  85253341.0  85083250-85253341
# 166           167    85253342  85427226.0  85253342-85427226
# 167           168    85427227  86072369.0  85427227-86072369
# 168           169    86072370         NaN          86072370-
#
#          reference_time          valid_time  \
# 0   2023-10-01 21:00:00 2023-10-01 21:00:00
# 1   2023-10-01 21:00:00 2023-10-01 21:00:00
# 2   2023-10-01 21:00:00 2023-10-01 21:00:00
# 3   2023-10-01 21:00:00 2023-10-01 21:00:00
# 4   2023-10-01 21:00:00 2023-10-01 21:00:00
# ..                  ...                 ...
# 164 2023-10-01 21:00:00 2023-10-01 21:00:00
# 165 2023-10-01 21:00:00 2023-10-01 21:00:00
# 166 2023-10-01 21:00:00 2023-10-01 21:00:00
# 167 2023-10-01 21:00:00 2023-10-01 21:00:00
# 168 2023-10-01 21:00:00 2023-10-01 21:00:00
#
#                                               variable              level  \
# 0                                                 REFC  entire atmosphere
# 1                                                RETOP          cloud top
# 2    var discipline=0 center=7 local_table=1 parmca...  entire atmosphere
# 3                                                  VIL  entire atmosphere
# 4                                                  VIS            surface
# ..                                                 ...                ...
# 164                                               ICEC            surface
# 165                                             SBT123  top of atmosphere
# 166                                             SBT124  top of atmosphere
# 167                                             SBT113  top of atmosphere
# 168                                             SBT114  top of atmosphere
#
#     forecast_time                                        search_this
# 0             anl                        :REFC:entire atmosphere:anl
# 1             anl                               :RETOP:cloud top:anl
# 2             anl  :var discipline=0 center=7 local_table=1 parmc...
# 3             anl                         :VIL:entire atmosphere:anl
# 4             anl                                   :VIS:surface:anl
# ..            ...                                                ...
# 164           anl                                  :ICEC:surface:anl
# 165           anl                      :SBT123:top of atmosphere:anl
# 166           anl                      :SBT124:top of atmosphere:anl
# 167           anl                      :SBT113:top of atmosphere:anl
# 168           anl                      :SBT114:top of atmosphere:anl
#
# [169 rows x 10 columns]
# Error loading variable SWDOWN:surface: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_68efb1fe__hrrr.t21z.wrfsfcf00.ak.grib2'
# Error loading variable LWDOWN:surface: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_68efb1fe__hrrr.t21z.wrfsfcf00.ak.grib2'
# Error loading variable TCDC:surface: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_68efb1fe__hrrr.t21z.wrfsfcf00.ak.grib2'
# Error loading variable SFC:soil moisture and temperature: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_68efb1fe__hrrr.t21z.wrfsfcf00.ak.grib2'
# Error loading variable U:10 m: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_68efb1fe__hrrr.t21z.wrfsfcf00.ak.grib2'
# Error loading variable V:10 m: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231001/subset_68efb1fe__hrrr.t21z.wrfsfcf00.ak.grib2'
# Saved hourly NetCDF: /home/cassie/data/hrrrak/netcdf/HRRR_AK_2023100121.nc
# Processing: 2023-10-01 22:00:00
# 💔 Did not find ┊ model=hrrrak ┊ product=sfc ┊ 2023-Oct-01 22:00 UTC F00
# Error processing 2023-10-01 22:00:00:
# No index file was found for None
# Download the full file first (with `H.download()`).
# You will need to remake the Herbie object (H = `Herbie()`)
# or delete this cached property: `del H.index_as_dataframe()`
# Processing: 2023-10-01 23:00:00
# 💔 Did not find ┊ model=hrrrak ┊ product=sfc ┊ 2023-Oct-01 23:00 UTC F00
# Error processing 2023-10-01 23:00:00:
# No index file was found for None
# Download the full file first (with `H.download()`).
# You will need to remake the Herbie object (H = `Herbie()`)
# or delete this cached property: `del H.index_as_dataframe()`
# Processing: 2023-10-02 00:00:00
# ✅ Found ┊ model=hrrrak ┊ product=sfc ┊ 2023-Oct-02 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
#      grib_message  start_byte    end_byte              range reference_time  \
# 0               1           0    473436.0           0-473436     2023-10-02
# 1               2      473437    587284.0      473437-587284     2023-10-02
# 2               3      587285   1231584.0     587285-1231584     2023-10-02
# 3               4     1231585   1662597.0    1231585-1662597     2023-10-02
# 4               5     1662598   2393299.0    1662598-2393299     2023-10-02
# ..            ...         ...         ...                ...            ...
# 164           165    82312399  82320436.0  82312399-82320436     2023-10-02
# 165           166    82320437  82489139.0  82320437-82489139     2023-10-02
# 166           167    82489140  82661807.0  82489140-82661807     2023-10-02
# 167           168    82661808  83275406.0  82661808-83275406     2023-10-02
# 168           169    83275407         NaN          83275407-     2023-10-02
#
#     valid_time                                           variable  \
# 0   2023-10-02                                               REFC
# 1   2023-10-02                                              RETOP
# 2   2023-10-02  var discipline=0 center=7 local_table=1 parmca...
# 3   2023-10-02                                                VIL
# 4   2023-10-02                                                VIS
# ..         ...                                                ...
# 164 2023-10-02                                               ICEC
# 165 2023-10-02                                             SBT123
# 166 2023-10-02                                             SBT124
# 167 2023-10-02                                             SBT113
# 168 2023-10-02                                             SBT114
#
#                  level forecast_time  \
# 0    entire atmosphere           anl
# 1            cloud top           anl
# 2    entire atmosphere           anl
# 3    entire atmosphere           anl
# 4              surface           anl
# ..                 ...           ...
# 164            surface           anl
# 165  top of atmosphere           anl
# 166  top of atmosphere           anl
# 167  top of atmosphere           anl
# 168  top of atmosphere           anl
#
#                                            search_this
# 0                          :REFC:entire atmosphere:anl
# 1                                 :RETOP:cloud top:anl
# 2    :var discipline=0 center=7 local_table=1 parmc...
# 3                           :VIL:entire atmosphere:anl
# 4                                     :VIS:surface:anl
# ..                                                 ...
# 164                                  :ICEC:surface:anl
# 165                      :SBT123:top of atmosphere:anl
# 166                      :SBT124:top of atmosphere:anl
# 167                      :SBT113:top of atmosphere:anl
# 168                      :SBT114:top of atmosphere:anl
#
# [169 rows x 10 columns]
# 👨🏻‍🏭 Created directory: [/home/cassie/data/hrrrak/20231002]
# Error loading variable SWDOWN:surface: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231002/subset_f8efb1fe__hrrr.t00z.wrfsfcf00.ak.grib2'
# Error loading variable LWDOWN:surface: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231002/subset_f8efb1fe__hrrr.t00z.wrfsfcf00.ak.grib2'
# Error loading variable TCDC:surface: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231002/subset_f8efb1fe__hrrr.t00z.wrfsfcf00.ak.grib2'
# Error loading variable SFC:soil moisture and temperature: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231002/subset_f8efb1fe__hrrr.t00z.wrfsfcf00.ak.grib2'
# Error loading variable U:10 m: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231002/subset_f8efb1fe__hrrr.t00z.wrfsfcf00.ak.grib2'
# Error loading variable V:10 m: [Errno 2] No such file or directory: '/home/cassie/data/hrrrak/20231002/subset_f8efb1fe__hrrr.t00z.wrfsfcf00.ak.grib2'
# Saved hourly NetCDF: /home/cassie/data/hrrrak/netcdf/HRRR_AK_2023100200.nc

# %% [markdown]
# ### Now that the data is downloaded, merge all the netcdfs into a single netcdf for use

# %%
# Step 2: Merge hourly NetCDF files into a single file
print("Merging all hourly files into a single NetCDF...")
try:
    # Find all hourly NetCDF files
    hourly_files = sorted(glob.glob(os.path.join(HOURLY_DIR, "*.nc")))

    # Open all datasets
    datasets = []
    for file in hourly_files:
        ds = xr.open_dataset(file)
        datasets.append(ds)

    # Concatenate datasets along the time dimension
    combined_ds = xr.concat(datasets, dim="time", combine_attrs="override")

    # Save the merged dataset
    combined_ds.to_netcdf(MERGE_FILE)
    print(f"Full-year NetCDF saved at: {MERGE_FILE}")
except Exception as e:
    print(f"Error merging hourly files: {e}")
# Out:
# Merging all hourly files into a single NetCDF...
# Full-year NetCDF saved at: /home/cassie/data/hrrrak/netcdf/netcdf_merge.nc

# %% [markdown]
# Now, take a look at the full NetCDF.

# %%
ds = xr.open_dataset(MERGE_FILE)
ds
# Out:
# <xarray.Dataset> Size: 406MB
# Dimensions:              (y: 919, x: 1299, time: 9)
# Coordinates:
#     latitude             (y, x) float64 10MB ...
#     longitude            (y, x) float64 10MB ...
#   * time                 (time) datetime64[ns] 72B 2023-10-01 ... 2023-10-02
#     valid_time           (time) datetime64[ns] 72B ...
#     step                 timedelta64[ns] 8B ...
#     heightAboveGround    float64 8B ...
#     gribfile_projection  float64 8B ...
#     surface              float64 8B ...
# Dimensions without coordinates: y, x
# Data variables:
#     t2m                  (time, y, x) float32 43MB ...
#     u10                  (time, y, x) float32 43MB ...
#     v10                  (time, y, x) float32 43MB ...
#     sh2                  (time, y, x) float32 43MB ...
#     sp                   (time, y, x) float32 43MB ...
#     vis                  (time, y, x) float32 43MB ...
#     tp                   (time, y, x) float32 43MB ...
#     orog                 (time, y, x) float32 43MB ...
#     r2                   (time, y, x) float32 43MB ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     model:                   hrrrak
#     product:                 sfc
#     description:             High-Resolution Rapid Refresh - Alaska
#     remote_grib:             https://noaa-hrrr-bdp-pds.s3.amazonaws.com/hrrr....
#     local_grib:              /home/cassie/data/hrrrak/20231001/subset_35ef9dd...
#     search:                  TMP:2 m

# %%
ds.herbie.polygon
# Out:
# (<POLYGON ((-3425051.029 -4098804.103, -3422051.029 -4098804.103, -3419051.02...>,
#  <POLYGON ((185.117 41.613, 185.142 41.628, 185.167 41.644, 185.191 41.659, 1...>)

# %%
ds.t2m.plot()
# Out:
# (array([1.700000e+01, 1.003000e+03, 3.493000e+04, 1.947120e+05,
#         6.017590e+05, 2.361947e+06, 1.639543e+06, 3.943640e+06,
#         1.949399e+06, 1.707900e+04]),
#  array([250.38499451, 254.50178528, 258.61859131, 262.73538208,
#         266.85217285, 270.96896362, 275.08575439, 279.20257568,
#         283.31936646, 287.43615723, 291.552948  ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# So that is the temperature for all the days downloaded

# %%
# Now plot t2m for a sinlge date 
ds.t2m.sel(time="2023-10-01 12:00").plot()

# %% [markdown]
# And now we have the temperature for a single point in time

# %%
# first just plot the whole region calling long and lat 
ds.t2m.sel(time="2023-10-01 12:00").plot(x="longitude", y="latitude")

# %%
ds.coords
# Out:
# Coordinates:
#     latitude             (y, x) float64 10MB ...
#     longitude            (y, x) float64 10MB ...
#   * time                 (time) datetime64[ns] 72B 2023-10-01 ... 2023-10-02
#     valid_time           (time) datetime64[ns] 72B ...
#     step                 timedelta64[ns] 8B ...
#     heightAboveGround    float64 8B ...
#     gribfile_projection  float64 8B ...
#     surface              float64 8B ...

# %%
ds.dims
# Out:
# FrozenMappingWarningOnValuesAccess({'y': 919, 'x': 1299, 'time': 9})

# %%
# rename the dimensions y to latitude and x to longitude
ds = ds.rename({"y": "latitude", "x": "longitude"})

# %%
ds.dims
# Out:
# FrozenMappingWarningOnValuesAccess({'latitude': 919, 'longitude': 1299, 'time': 9})

# %% [markdown]
# And, we want to clip this area to a region around Juneau.

# %%
# Check the range of latitude and longitude in the dataset
print("Latitude range:", ds.latitude.min().values, "to", ds.latitude.max().values)
print("Longitude range:", ds.longitude.min().values, "to", ds.longitude.max().values)
# Out:
# Latitude range: 41.612949 to 77.09289230325162
# Longitude range: 156.43684261143042 to 244.2242628421437

# %% [markdown]
# The longitude range is off here.\
# Latitude: The latitude range in your dataset (41.61 to 77.09) does include the latitude of Juneau, Alaska (approximately 58.30).\
# Longitude: The longitude range (156.44 to 244.22) is problematic. The longitude for Juneau is approximately -134.42, which is not within the range of your dataset.
#
# The longitude values in the dataset appear to be in a different range than expected. The values (156.44 to 244.22) suggest that they might be in a different coordinate system or representation (e.g., they could be in a different projection or might need to be adjusted).

# %%
ds = ds.herbie.to_180() # using the herbie.accessor method to convert to 180

# %%
# Check the range of latitude and longitude in the dataset
print("Latitude range:", ds.latitude.min().values, "to", ds.latitude.max().values)
print("Longitude range:", ds.longitude.min().values, "to", ds.longitude.max().values)
# Out:
# Latitude range: 41.612949 to 77.09289230325162
# Longitude range: -179.98534065320598 to 179.98956853173223

# %%
ds.herbie.crs
# Out:
# <Projected CRS: +proj=stere +ellps=sphere +a=6371229.0 +b=6371229. ...>
# Name: unknown
# Axis Info [cartesian]:
# - E[south]: Easting (metre)
# - N[south]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unknown
# - method: Polar Stereographic (variant B)
# Datum: unknown
# - Ellipsoid: unknown
# - Prime Meridian: Greenwich

# %%
# to use later, there is a herbie.with_wind accessor method that can be used to calculate wind speed and direction

# %%
ds.dims
# Out:
# FrozenMappingWarningOnValuesAccess({'latitude': 919, 'longitude': 1299, 'time': 9})

# %%
ds = ds.rio.set_spatial_dims(x_dim='longitude', y_dim='latitude', inplace=True)

# %%
ds.rio.spatial_dims
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[241], line 1
# ----> 1 ds.rio.spatial_dims
#
# AttributeError: 'RasterDataset' object has no attribute 'spatial_dims'

# %%
# ds = ds.assign_coords({'latitude': (('y', 'x'), ds.latitude), 'longitude': (('y', 'x'), ds.longitude)})

# %%
# # open the file fresh in case I made changes...
# ds = xr.open_dataset(MERGE_FILE)

# # Check the current CRS
# print(ds.rio.crs)

# # Set the CRS to the original projection (Polar Stereographic)
# wkt_string = (
#     "PROJCS['unknown',"
#     "GEOGCS['unknown',"
#     "DATUM['unknown',"
#     "SPHEROID['unknown',6371229,0]],"
#     "PRIMEM['Greenwich',0,AUTHORITY['EPSG','8901']],"
#     "UNIT['degree',0.0174532925199433]],"
#     "PROJECTION['Polar_Stereographic'],"
#     "PARAMETER['latitude_of_origin',60],"
#     "PARAMETER['central_meridian',225],"
#     "PARAMETER['false_easting',0],"
#     "PARAMETER['false_northing',0],"
#     "UNIT['metre',1,AUTHORITY['EPSG','9001']],"
#     "AXIS['Easting',SOUTH],"
#     "AXIS['Northing',SOUTH]"
#     "]"
# )

# # Write the CRS to the dataset
# ds.rio.write_crs(wkt_string, inplace=True)

# # Adjust longitude values from 0-360 to -180 to 180
# ds['longitude'] = xr.where(ds.longitude > 180, ds.longitude - 360, ds.longitude)

# # Set spatial dimensions
# ds.rio.set_spatial_dims(x_dim='longitude', y_dim='latitude', inplace=True)

# # Reproject to a new CRS (e.g., EPSG:4326)
# ds_proj = ds.rio.reproject("EPSG:4326")

# # Save the reprojected dataset
# ds_proj.to_netcdf('reprojected_dataset.nc', format='NETCDF4')

# %%
# Check the range of latitude and longitude in the dataset
print("Latitude range:", ds.latitude.min().values, "to", ds.latitude.max().values)
print("Longitude range:", ds.longitude.min().values, "to", ds.longitude.max().values)
# Out:
# Latitude range: 41.612949 to 77.09289230325162
# Longitude range: -179.98534065320595 to 179.98956853173223

# %%
# rename the latitude to y and longitude to x
# ds = ds.rename({'latitude': 'y', 'longitude': 'x'})

# ds = ds.rename({'x': 'longitude', 'y': 'latitude'})

# %%
ds = xr.open_dataset(MERGE_FILE)

# Set the CRS to EPSG:3411 (North Polar Stereographic)
ds.rio.write_crs("EPSG:3411", inplace=True) # writing the crs from the original file, ds.herbie.crs 
print(ds.rio.crs)

ds = ds.rename({'x': 'longitude', 'y': 'latitude'})

# Set spatial dimensions
ds.rio.set_spatial_dims(x_dim='longitude', y_dim='latitude', inplace=True)

# Verify the spatial dimensions are set
print("Spatial Dimensions:", ds.rio.spatial_dims)

# Now reproject the dataset to EPSG:32608 (UTM Zone 8N)
ds_reprojected = ds.rio.reproject("EPSG:32608")

# Optionally, save the reprojected dataset to a new file
ds_reprojected.to_netcdf('reprojected_dataset.nc', format='NETCDF4')

# Print the reprojected dataset to verify
print(ds_reprojected)
# Out:
# EPSG:3411
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[249], line 13
#      10 ds.rio.set_spatial_dims(x_dim='longitude', y_dim='latitude', inplace=True)
#      12 # Verify the spatial dimensions are set
# ---> 13 print("Spatial Dimensions:", ds.rio.spatial_dims)
#      15 # Now reproject the dataset to EPSG:32608 (UTM Zone 8N)
#      16 ds_reprojected = ds.rio.reproject("EPSG:32608")
#
# AttributeError: 'RasterDataset' object has no attribute 'spatial_dims'

# %%
# Load your dataset
ds = xr.open_dataset(MERGE_FILE)

# Check and write the CRS of the original dataset (use the correct CRS)
crs_original = "EPSG:3411"  # Replace with the actual CRS of your dataset
ds = ds.rio.write_crs(crs_original, inplace=True)

# Rename dimensions if needed (e.g., x -> longitude, y -> latitude)
if 'x' in ds.dims and 'y' in ds.dims:
    ds = ds.rename({'x': 'longitude', 'y': 'latitude'})

# Assign spatial coordinates if they are not explicitly set
if 'longitude' not in ds.coords or 'latitude' not in ds.coords:
    ds = ds.assign_coords(
        longitude=(('latitude', 'longitude'), ds['longitude'].values),
        latitude=(('latitude', 'longitude'), ds['latitude'].values)
    )

# Set spatial dimensions explicitly for rioxarray
ds = ds.rio.set_spatial_dims(x_dim='longitude', y_dim='latitude')

# Check if spatial dimensions and CRS are set correctly
print("Current CRS:", ds.rio.crs)

# Reproject the dataset to EPSG:32608 (UTM Zone 8N)
ds_reprojected = ds.rio.reproject("EPSG:32608")

# Optionally, save the reprojected dataset to a new file
ds_reprojected.to_netcdf("reprojected_dataset.nc", format="NETCDF4")

# Print confirmation
print("Reprojection successful. Saved as 'reprojected_dataset.nc'.")
# Out:
# Current CRS: EPSG:3411
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[250], line 26
#      23 print("Current CRS:", ds.rio.crs)
#      25 # Reproject the dataset to EPSG:32608 (UTM Zone 8N)
# ---> 26 ds_reprojected = ds.rio.reproject("EPSG:32608")
#      28 # Optionally, save the reprojected dataset to a new file
#      29 ds_reprojected.to_netcdf("reprojected_dataset.nc", format="NETCDF4")
#
# File ~/programs/miniforge3/envs/herbie/lib/python3.13/site-packages/rioxarray/raster_dataset.py:122, in RasterDataset.reproject(self, dst_crs, resolution, shape, transform, resampling, nodata, **kwargs)
#     119 try:
#     120     x_dim, y_dim = _get_spatial_dims(self._obj, var=var)
#     121     resampled_dataset[var] = (
# --> 122         self._obj[var]
#     123         .rio.set_spatial_dims(x_dim=x_dim, y_dim=y_dim, inplace=True)
#     124         .rio.reproject(
#     125             dst_crs,
#     126             resolution=resolution,
#     127             shape=shape,
#     128             transform=transform,
#     129             resampling=resampling,
#     130             nodata=nodata,
#     131             **kwargs,
#     132         )
#     133     )
#     134 except MissingSpatialDimensionError:
#     135     if len(self._obj[var].dims) >= 2 and not get_option(
#     136         SKIP_MISSING_SPATIAL_DIMS
#     137     ):
#
# File ~/programs/miniforge3/envs/herbie/lib/python3.13/site-packages/rioxarray/raster_array.py:468, in RasterArray.reproject(self, dst_crs, resolution, shape, transform, resampling, nodata, **kwargs)
#     461     kwargs.setdefault("gcps", gcps)
#     463 use_affine = (
#     464     "gcps" not in kwargs
#     465     and "rpcs" not in kwargs
#     466     and "src_geoloc_array" not in kwargs
#     467 )
# --> 468 src_affine = None if not use_affine else self.transform(recalc=True)
#     469 if transform is None:
#     470     dst_affine, dst_width, dst_height = _make_dst_affine(
#     471         src_data_array=self._obj,
#     472         src_crs=self.crs,
#    (...)
#     476         **kwargs,
#     477     )
#
# File ~/programs/miniforge3/envs/herbie/lib/python3.13/site-packages/rioxarray/rioxarray.py:707, in XRasterBase.transform(self, recalc)
#     704     return transform
#     706 try:
# --> 707     src_left, _, _, src_top = self._unordered_bounds(recalc=recalc)
#     708     src_resolution_x, src_resolution_y = self.resolution(recalc=recalc)
#     709 except (DimensionMissingCoordinateError, DimensionError):
#
# File ~/programs/miniforge3/envs/herbie/lib/python3.13/site-packages/rioxarray/rioxarray.py:1079, in XRasterBase._unordered_bounds(self, recalc)
#    1062 def _unordered_bounds(
#    1063     self, recalc: bool = False
#    1064 ) -> tuple[float, float, float, float]:
#    1065     """
#    1066     Unordered bounds.
#    1067
#    (...)
#    1077         Outermost coordinates of the `xarray.DataArray` | `xarray.Dataset`.
#    1078     """
# -> 1079     resolution_x, resolution_y = self.resolution(recalc=recalc)
#    1081     try:
#    1082         # attempt to get bounds from xarray coordinate values
#    1083         left, bottom, right, top = self._internal_bounds()
#
# File ~/programs/miniforge3/envs/herbie/lib/python3.13/site-packages/rioxarray/rioxarray.py:1046, in XRasterBase.resolution(self, recalc)
#    1043 # if the coordinates of the spatial dimensions are missing
#    1044 # use the cached transform resolution
#    1045 try:
# -> 1046     left, bottom, right, top = self._internal_bounds()
#    1047 except DimensionMissingCoordinateError:
#    1048     if transform is None:
#
# File ~/programs/miniforge3/envs/herbie/lib/python3.13/site-packages/rioxarray/rioxarray.py:1009, in XRasterBase._internal_bounds(self)
#    1007     raise DimensionMissingCoordinateError(f"{self.y_dim} missing coordinates.")
#    1008 try:
# -> 1009     left = float(self._obj[self.x_dim][0])
#    1010     right = float(self._obj[self.x_dim][-1])
#    1011     top = float(self._obj[self.y_dim][0])
#
# File ~/programs/miniforge3/envs/herbie/lib/python3.13/site-packages/xarray/core/common.py:157, in AbstractArray.__float__(self)
#     156 def __float__(self: Any) -> float:
# --> 157     return float(self.values)
#
# TypeError: only length-1 arrays can be converted to Python scalars

# %%
ds.rio.spatial_dims
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[252], line 1
# ----> 1 ds.rio.spatial_dims
#
# AttributeError: 'RasterDataset' object has no attribute 'spatial_dims'

# %%
# Check the range of latitude and longitude in the dataset
print("Latitude range:", ds.latitude.min().values, "to", ds.latitude.max().values)
print("Longitude range:", ds.longitude.min().values, "to", ds.longitude.max().values)
# Out:
# Latitude range: 41.612949 to 77.09289230325162
# Longitude range: 156.43684261143042 to 244.2242628421437

# %%
# first just plot the whole region calling long and lat 
ds.t2m.sel(time="2023-10-01 12:00").plot(x="longitude", y="latitude")

# %%
ds = ds.herbie.to_180() # using the herbie.accessor method to convert to 180

# %%
# first just plot the whole region calling long and lat 
ds.t2m.sel(time="2023-10-01 12:00").plot(x="longitude", y="latitude")

# %%
ds.rio.crs
# Out:
# CRS.from_wkt('PROJCS["NSIDC Sea Ice Polar Stereographic North",GEOGCS["Hughes 1980",DATUM["Hughes_1980",SPHEROID["Hughes 1980",6378273,298.279411123064,AUTHORITY["EPSG","7058"]],AUTHORITY["EPSG","1359"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","10345"]],PROJECTION["Polar_Stereographic"],PARAMETER["latitude_of_origin",70],PARAMETER["central_meridian",-45],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",SOUTH],AXIS["Northing",SOUTH],AUTHORITY["EPSG","3411"]]')

# %% [markdown]
# Testing merge types, merge vs concat

# %%
# ds1 = xr.open_dataset("/home/cassie/data/hrrrak/netcdf/HRRR_AK_2023100100.nc")
# ds2 = xr.open_dataset("/home/cassie/data/hrrrak/netcdf/HRRR_AK_2023100103.nc")
# ds3 = xr.open_dataset("/home/cassie/data/hrrrak/netcdf/HRRR_AK_2023100106.nc")

# combined_concat= xr.concat([ds1, ds2, ds3], dim="time")
# combined_concat

# combined_merge = xr.merge([ds1, ds2, ds3], compat="override")
# combined_merge

# %% [markdown]
# ### This is basically the same code for downloading,
# but it's giving us more info about the data which is not downloading (hourly)

# %%
# Define parameters
START_DATE = "2023-10-01"  # Change to desired start date
END_DATE = "2023-10-02"    # Change to desired end date
MODEL = "hrrrak"           # HRRR-AK model
SUBMODEL = "ak"            # Alaska-specific domain
VARIABLES = ["TMP:2 m", "UGRD:10 m", "VGRD:10 m"]  # Example variables to download

# Paths for saving files
HOURLY_DIR = "/home/cassie/data/hrrrak/netcdf"  # Directory for hourly files
FULL_YEAR_FILE = "/home/cassie/data/hrrrak/netcdf/netcdf_merge_test.nc"  # Final merged file

# Create directories if they don't exist
os.makedirs(HOURLY_DIR, exist_ok=True)

# Generate a date range for downloading
date_range = pd.date_range(START_DATE, END_DATE, freq="1h")

# Step 1: Download hourly HRRR-AK data
for date in date_range:
    try:
        print(f"Processing: {date}")
        h = Herbie(date, model=MODEL, product="sfc", domain=SUBMODEL)

        # Download the full file if necessary
        h.download()  # Ensure the full file is downloaded

        # Recreate the Herbie object after download
        h = Herbie(date, model=MODEL, product="sfc", domain=SUBMODEL)

        # Initialize an empty list to store datasets
        datasets = []

        # Loop through each variable and load
        for variable in VARIABLES:
            try:
                ds = h.xarray(variable)
                datasets.append(ds)
            except Exception as e:
                print(f"Error loading variable {variable}: {e}")

        # Merge all datasets, overriding metadata conflicts
        if datasets:
            combined_ds = xr.merge(datasets, compat="override")

            # Save hourly NetCDF
            netcdf_path = os.path.join(HOURLY_DIR, f"HRRR_AK_{date.strftime('%Y%m%d%H')}.nc")
            combined_ds.to_netcdf(netcdf_path)
            print(f"Saved hourly NetCDF: {netcdf_path}")
    except Exception as e:
        print(f"Error processing {date}: {e}")

# Step 2: Merge hourly NetCDF files into a single file
print("Merging all hourly files into a single NetCDF...")
try:
    # Find all hourly NetCDF files
    hourly_files = sorted(glob.glob(os.path.join(HOURLY_DIR, "*.nc")))

    # Open all datasets
    datasets = []
    for file in hourly_files:
        ds = xr.open_dataset(file)
        datasets.append(ds)

    # Concatenate datasets along the time dimension
    combined_ds = xr.concat(datasets, dim="time", combine_attrs="override")

    # Save the merged dataset
    combined_ds.to_netcdf(FULL_YEAR_FILE)
    print(f"Full-year NetCDF saved at: {FULL_YEAR_FILE}")
except Exception as e:
    print(f"Error merging hourly files: {e}")
# Out:
# Processing: 2023-10-01 00:00:00
# ✅ Found ┊ model=hrrrak ┊ product=sfc ┊ 2023-Oct-01 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# 👨🏻‍🏭 Created directory: [/home/cassie/data/hrrrak/20231001]
# ✅ Found ┊ model=hrrrak ┊ product=sfc ┊ 2023-Oct-01 00:00 UTC F00 ┊ GRIB2 @ local ┊ IDX @ aws
# Error processing 2023-10-01 00:00:00: Invalid value for attr 'remote_grib': PosixPath('/home/cassie/data/hrrrak/20231001/hrrr.t00z.wrfsfcf00.ak.grib2'). For serialization to netCDF files, its value must be of one of the following types: str, Number, ndarray, number, list, tuple, bytes
# Processing: 2023-10-01 01:00:00
# 🦨 GRIB2 file not found: self.model='hrrrak' self.date=Timestamp('2023-10-01 01:00:00') self.fxx=0
# 💔 Did not find ┊ model=hrrrak ┊ product=sfc ┊ 2023-Oct-01 01:00 UTC F00
# 💔 Did not find ┊ model=hrrrak ┊ product=sfc ┊ 2023-Oct-01 01:00 UTC F00
# Error loading variable TMP:2 m:
# No index file was found for None
# Download the full file first (with `H.download()`).
# You will need to remake the Herbie object (H = `Herbie()`)
# or delete this cached property: `del H.index_as_dataframe()`
# Error loading variable UGRD:10 m:
# No index file was found for None
# Download the full file first (with `H.download()`).
# You will need to remake the Herbie object (H = `Herbie()`)
# or delete this cached property: `del H.index_as_dataframe()`
# Error loading variable VGRD:10 m:
# No index file was found for None
# Download the full file first (with `H.download()`).
# You will need to remake the Herbie object (H = `Herbie()`)
# or delete this cached property: `del H.index_as_dataframe()`
# Processing: 2023-10-01 02:00:00
# 🦨 GRIB2 file not found: self.model='hrrrak' self.date=Timestamp('2023-10-01 02:00:00') self.fxx=0
# 💔 Did not find ┊ model=hrrrak ┊ product=sfc ┊ 2023-Oct-01 02:00 UTC F00
# 💔 Did not find ┊ model=hrrrak ┊ product=sfc ┊ 2023-Oct-01 02:00 UTC F00
# Error loading variable TMP:2 m:
# No index file was found for None
# Download the full file first (with `H.download()`).
# You will need to remake the Herbie object (H = `Herbie()`)
# or delete this cached property: `del H.index_as_dataframe()`
# Error loading variable UGRD:10 m:
# No index file was found for None
# Download the full file first (with `H.download()`).
# You will need to remake the Herbie object (H = `Herbie()`)
# or delete this cached property: `del H.index_as_dataframe()`
# Error loading variable VGRD:10 m:
# No index file was found for None
# Download the full file first (with `H.download()`).
# You will need to remake the Herbie object (H = `Herbie()`)
# or delete this cached property: `del H.index_as_dataframe()`
# Processing: 2023-10-01 03:00:00
# ✅ Found ┊ model=hrrrak ┊ product=sfc ┊ 2023-Oct-01 03:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[74], line 25
#      22 h = Herbie(date, model=MODEL, product="sfc", domain=SUBMODEL)
#      24 # Download the full file if necessary
# ---> 25 h.download()  # Ensure the full file is downloaded
#      27 # Recreate the Herbie object after download
#      28 h = Herbie(date, model=MODEL, product="sfc", domain=SUBMODEL)
#
# File ~/programs/miniforge3/envs/herbie/lib/python3.13/site-packages/herbie/core.py:1045, in Herbie.download(self, search, searchString, source, save_dir, overwrite, verbose, errors)
#    1040 # ===============
#    1041 # Do the Download
#    1042 # ===============
#    1043 if search in [None, ":"] or self.idx is None:
#    1044     # Download the full file from remote source
# -> 1045     urllib.request.urlretrieve(self.grib, outFile, _reporthook)
#    1047     original_source = self.grib
#    1049     self.grib = outFile
#
# File ~/programs/miniforge3/envs/herbie/lib/python3.13/urllib/request.py:242, in urlretrieve(url, filename, reporthook, data)
#     239 if reporthook:
#     240     reporthook(blocknum, bs, size)
# --> 242 while block := fp.read(bs):
#     243     read += len(block)
#     244     tfp.write(block)
#
# File ~/programs/miniforge3/envs/herbie/lib/python3.13/http/client.py:479, in HTTPResponse.read(self, amt)
#     476 if self.length is not None and amt > self.length:
#     477     # clip the read to the "end of response"
#     478     amt = self.length
# --> 479 s = self.fp.read(amt)
#     480 if not s and amt:
#     481     # Ideally, we would raise IncompleteRead if the content-length
#     482     # wasn't satisfied, but it might break compatibility.
#     483     self._close_conn()
#
# File ~/programs/miniforge3/envs/herbie/lib/python3.13/socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File ~/programs/miniforge3/envs/herbie/lib/python3.13/ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File ~/programs/miniforge3/envs/herbie/lib/python3.13/ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:
